# %% [markdown]
# # RNN Model
# ## Maren, Sophia & Malin - Group 4

# %% [markdown]
# Dies ist ein RNN, welches ein "word-level-model" ist. Als Input nimmt es eine .txt Datei mit Tweets einer Partei. Als Output generiert es einen neuen Tweet dieser Partei von einer beliebig wählbaren Länge.

# %%
# Pakete, die wir brauchen
import numpy as np
import tensorflow as tf
import random 
import matplotlib.pyplot as plt
import scipy.io
from nltk.tokenize import RegexpTokenizer
from collections import Counter
import pandas as pd
import re
import string

# zusätzliche Pakete für eine weitere Methode zu tokenisieren
import nltk
from nltk import word_tokenize
from nltk.tokenize import TreebankWordTokenizer

# %% [markdown]
# ### Hilfsfunktion

# %%
''' Die Funktion "additonal cleaning" bearbeiten nocheinmal die .txt files nach. Dies sind Dinge, die uns erst nach dem Erstellen
    der .txt Dateien aufgefallen sind und beim Preprocessing übersehen wurden. Das Erstellen der Files hat so lange gedauert,
    dass es uns leichter erschien, dies nachträglich zu machen, als das Preprocessing nochmal mit der erweiterten Funktion laufen zu lassen,
    Dennoch ist uns bewusst, dass das "sauberer" wäre
    Die Funktion löscht alle html links, Dinge die auf @ folgen, einige Sonderzeichen und ungewünschte Satzzeichen
    Input: eine Textdatei
    Output: die Textdetei ohne die unerwünschten Zeichen
'''
def additional_cleaning(text):
    # löscht unerwünschte Zeichen
    text = re.sub(r"…", "", text)
    text = re.sub(r". . . ", "", text)
    text = re.sub(r"r'\S+", "", text)
    #text = re.sub(r"#", "# ", text)
    text = re.sub(r"&amp", "", text)
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"”", "", text)
    text = re.sub(r"’", "", text)
    text = re.sub(r"•", "", text)
    #text = re.sub(r"+", "", text)
    text = re.sub(r"»", "", text)
    text = re.sub(r"|", "", text)
    text = re.sub(r"«", "", text)
    text = re.sub(r"%", "", text)
    text = ''.join( c for c in text if  c not in '],[,/,:,&,_,1,2,3,4,5,6,7,8,9,0,\,&,;,-,),(,?,!')
   
    # wir möchten alle Buchstaben klein machen, um das Vokabular zu verringern
    text = text.lower()
    

    return text

# %% [markdown]
# ### Einlesen der Daten

# %%
# Öffnen unserer .txt files
text_char = open("GRUENE.txt",'r').read()

# andere Wege um die Datei zu öffnen, abhängig davon, ob alle benötigten Pakete installiert sind

# 2. Möglichkeit
#with open("tweets.txt", 'rb') as f:
#text_char = f.read()
    
# 3. Möglichkeit - klappt am häufigsten, wirft aber smileys etc weg
#with open("tweets/GRUENE.txt", encoding="utf8", errors='ignore') as f:
#   text_char = f.read()

# %%
# wendet die oben definierte additional_cleaning Funktion auf den Text an
input_text = additional_cleaning(text_char)

# %%
# Dies printet den Inhalt der .txt Datei, um einen Eindruck davon zu bekommen, wie der Input aussieht
print( "Input text: {}".format (input_text))
# Out:
# Input text:  „verlierer sind verbraucher und umwelein kommentar zum #dieselgipfel von ist mehr als nur glasfaser verbuddeln rahmensetzung  gezielte foerderung guter ideen ausgespaeht geschwaerzt vertuscht diskussion zu geheimdiensten mit und es ist zeit voran zu gehen . anpacken statt aussitzen . fuer eine mutige gruene politik . auf in den wahlkampf #darumgrün  wir diskutieren das wahlprogramm . sieht die praeambel als gute grundlage in die offensive zu gehen .  so geht echte radlhauptstadt . take that gut umweltaktion des kidsclub am stadion . genug schwarzgeaergert . zukunft ist waehlbar #darumgrün  in berlinmitte erststimme mutlu  zweitstimme nun zum infostand zur #btw von in die innenstadt #leipzig . #zukunftwirdausmutgemacht die schirmherrinnen des lernlabors #morgenmehr trude #simonsohn und pressmitteilung starbucks in #berlinmitte getestet  die sprechen deutsch  uff weshalb sie die vorschlaege z antiterrorpolitik ablehnt hat mir gesagt bin mal gespannt wie der vergleich koavertrag schwarzgelb #nrw und #jamaika sh ausfaellt . happy birthday #erasmusplus  years  million participants  a big success story for europe am  . sep . nicht iist sollte briefwahlunterlagen beantragen . jede stimme zaehlt waehrend manche die automobilindustrie im #abgasskandal noch schuetzen wollen findet mdb klare worte schauen sie sich gern mal unsere alternative zu den sog . sicheren herkunftslaendern an get #vds abgesagt . #ehefueralle angesagt . alle reden ueber #emissionsfrei soll mal keiner mehr behaupten wir  jahre groko leider  verlorene jahre fuer die#abruestung  hoechste zeit fuer mehr mut #zukunftwirdausmutgemacht vielen dank an alle freifunkerinnen  freifunker die trotz schlechter rechtslage agieren .  gruene oder fdp  das ist eine wahlauseinandersetzung die ich gerne fuehre . forsa die haelfte der befragten wuenschen sich eine regierungsbeteiligung von #annewill wtf furchtbare bilder katastrophale folgen fuer die menschen in betroffenen regionenwir muessen jetzt endlich handeln uberfahrer wie die tageloehner im  . jahrhundert risiken fuer fahrer hoch fuer uber gering danke . klappt .  falsch weiter so gute nachricht fuer laut #bfh duerfen #gemeinnuetzige organisationen ueberparteilich politisch taetig sein .   nicht ihre krise dass die #gruenen schwach sind zeigt dass gesellschaft und öffentlichkeit sich von der ökologie  habe gerade den aufruf von luise #amtsberg zur freiheit von #guenalkurşun unterzeichnet an dieser antisemitischen #bdsbewegung hat der nen narren gefressen . und in schwoeren #merkel dem #diesel fast taeglich noch jahrzehntelange treue .  neue #btw twitter analyse demnaechst . erstes preview anbei heute war ich mit uwe kekeritz  unterwegs . zuerst bem fuerther treffpunkt  waermestube . anschiessend . schonmal vormerken kommt nach #muenchen und steht rede und antwort zu gruener politik aseptember wir wollen familien besser foerdern  und ich gestern in muenster zum gruenen familienbudget #gruene forderungen zur #sozialpolitik übernahme angemessener #wohnkosten sicherstellen#grundsicherung  warum gruenr#darumgruen rr und die gesellschaft diese ganze traurige #tvduellsache . #klartextwir sagen herzlich danke euch allen fuer euer engagement eure arbeieuren einsatz fuer gruen #ldknrw berlin leben waehlen toller politiker toller mensch  meine stimme als direkter abgeordneter   özoguzbeleidigung exbundesrichter zeigt gauland wegen volksverhetzung an es geht los . kino barrierefrei im dgbhaus ein paar plaetze sind noch frei .  sensationelle szene widobrindt im zdf beim thema #diesel demontiert – ausgerechnet unter  danke und was steht da drin abschreiben von den herstellern ist ueblich macht es das besser nein . david bonderman kuendigte nach dieser aussage seinen ruecktritt an . mehr dazu versklavte jesidinnen der is haelt immer noch mehr als  frauen gefangen via und laute demo gegen den #afd landesparteitag in #walsrode . wir streiten fuer sozialund menschenrechte statt freue mich auf die diskussion ueber #rechtsextremismus ...
# freue mich auf  mit dem code countdown gibt es hier  tickets zu allen spielen das insektensterben in deutschland nimmt immer weiter zu . was das fuer folgen das fuer natur und umwelt hat . #planete afd fdp csu  alle haben behauptet in bueros gelten viel hoehere grenzwerte fuer stickstoffdioxid als auf der strasse   das bild des tages ist damit wohl gefunden . alles tanzt #gso #gso alles keine utopie .  die kohle abschalten geht . natuerlich . zeigt die studie . dafuer arbeiten wir ich bin vorhin auch mit redenschirm nass geworden . es ist einfach zuviel wasser unterwegs  mit vor debatte zur einrichtung eines unsonderbeauftragten fuer #pressefreiheit und schutz von journalisten   important piece on russian election meddling . this time in germany . brauchen eine dringende #bildungsoffensive fuer mehr #bildungsgerechtigkeit waere ja schoen . aber leider nur die halbe wahrheit . hintertueren fuer die #privatisierung der #autobahnen bleiben offen  stephan mayer #csu wettert im #bundestag gegen den familiennachzug von gefluechteten . rechtswidrig und familienfeindlich widerwaertig spannende termine heute mit im lk #verden zu #buergerenergie #nofracking risiken erdgasfoerderung in  wenn im fokus ist seit wann wissen sie dass sie mit der bei wahlen antritt rueckblick im juni  wurden #stolpersteine vor dem dt . bundestag in erinnerung an fruehere juedische einwohner  verhaengt rekordstrafe gegen #ehefueralle  warum merkel ploetzlich nicht mehr mauert  gewonnen haben . schwarzgelb regierung in nrw hat schon  bis  windkraft ausgebremst und damit tausende von arbeitsplaetzen   romain schneider  carole dieschbourg met today with deputy sg can count on #luxembourg for ministers romain #schneider  met with new administrator in margins of #hlpf  full statement by minister on behalf of  member states of group of friends of #children tuerkeistaemmige berliner*innen demonstrieren fuer #rechtsstaatlichkeit in der #tuerkei und bilden eine menschenkette  das ende des verbrennungsmotors so ist  machbar #cdu hat jahrelang gegen jede art von kollektiver rechtsdurchsetzung gekaempft  jede stimme zaehlt im september 🌻🌻🌻 darum #briefwahl beantragen und waehlen wann und wo ihr wollt #mutludirekt ✉️ gruene plaedieren im dieselskandal fuer strafen fuer autobauer die manipulieren eine fuer alle  plaedoyer fuer #buergerversicherungartikel ueber eine veranstaltung in #viernheim . mit seiner einstellung hatte es #arppe immerhin zum vize in der #afd fraktion in meckpom geschaft .   soil could be the key to combatting carbon based greenhouse gas by storing carbon under our feet  die afd luegt wissentlich sie schuert hass  hetze . dem begegnen wir mit haltung den mitteln des rechtsstaates   fdp contra #elektromobilitaet mit schlagender logik weil wir heute braunkohle verbrennen muessen wir auch morgen noch mit erdoel fahren  und tschuess besser #trump verlaesst #paris #klimaabkommen als dass er alles blockiert . vorreiter werden profitieren . der alte fritz hat sie entfaehrt .  ich habe schon vor ueber  jahren auf dem #motzstrassenfest mit anderen trauungen vorgefuehrt . wo ist die eile . ich komme jetzt auch endlich . freitag nach dienstschluss kam änderungsantrag #stpo . heut an ausschuss . #groko wollte um  .  sondersitzung . besser waere gewesen wenn die #spd uns unterstuetzt haette die fuehrung das ist doch langweili. gibts dort kein efes  . jens muss mal die parallelgesellschaft entweder schluss mit kohle oder schluss mit klima . #darumgrün #btw nur wer chancen bekommt kann chancen nutzen . #darumgrün #btw wenn man gleich viel leistet sollte frau auch gleich viel verdienen . #darumgrün #btw kinderarmut kann man kleinreden . oder gross bekaempfen . #darumgrün #btw gesundes essen kommt nicht aus einer kranken natur . #darumgrün #btw umwelt ist nicht alles . aber ohne umwelt ist alles nichts . #darumgrün #btw es ist zeit voran zu gehen . anpacken statt aussitzen . fuer eine mutige gruene politik . auf in den wahlkampf #darumgrün #btw die motive unserer plakatk ...

# %% [markdown]
# ### Generieren des Vokabulars

# %%
# Wir haben verschiede Versionen ausprobiert um den Text zu tokenisieren
# Sie haben alle ihre Vor- und Nachteile, manche beschleunigen das Training, aber dafür streichen sie alle Sonderzeichen,
# andere wiederum sind langsamer, weil alle Sonderzeichen als einzelne "Wörter" interpretiert werden etc
# Wir haben uns für die 4. Version entschieden, da sie ein guter Mittelweg ist das Vokabular klein zu halten und trotzdem
# Smileys etc zu lernen.

# 1. Möglichkeit - hier bleiben keine Punkte drin
#tokenized_text = list(input_text.split(" "))
#vocab = set(tokenized_text)

# 2. Möglichkeit - einzelne Buchstaben und Satzzeichen sind weg
#tokenizer = RegexpTokenizer(r'\w+')
#tokenized_text = list(tokenizer.tokenize(text_char))
#vocab = set(tokenized_text)

# 3. Möglichkeit - hier werden alle Leerzeichen, Satzzeichen ets als einzelne "Wörter" interpretiert
# dadurch ist dieser Ansatz sehr langsam
#p2 = re.compile(r'(\W+)')
#tokenized_text = p2.split(input_text)

# 4. Möglichkeit - behält smileys, Leerzeichen werden manuell am Ende wieder eingefügt
vocab = TreebankWordTokenizer()
tokenized_text = vocab.tokenize(input_text)

vocab = set(tokenized_text)
vocab_size = len(vocab)

print("vocabulary size: {}".format(vocab_size))

text_length = len(tokenized_text)
print("text length: {}".format(text_length))
# Out:
# vocabulary size: 3684
# text length: 10962

# %% [markdown]
# ### Erstellen von einer Übersetzung Wort - ID

# %%
# Erstelle dictionaries um zwischen Wörtern und ihren IDs (Nummern) hin und her zu wechseln
word_to_id = { word:i for i, word in enumerate(vocab)}
id_to_word = {i:word for i, word in enumerate(vocab)}


# Übersetze die gesammte .txt Datei aller Tweets in Nummern (= die zugehörigen IDs der Wörter)
text_as_id = [word_to_id[c] for c in tokenized_text]

print("Translation word:id : {}".format(word_to_id))
# Out:
# Translation word:id : {'naehe': 0, 'stehe': 1, 'buntenbach': 2, 'rueckblick': 3, 'weltretten': 4, 'verhandeln': 5, 'administrator': 6, 'flughafen': 7, 'kaffeehaus': 8, 'rahmensetzung': 9, 'ab': 10, 'lautet': 11, 'schon': 12, 'liebkaempft': 13, 'umweltaktion': 14, 'abhaengt': 15, 'vermissen': 16, 'volker': 17, 'jeder': 18, 'israel': 19, 'ueberparteilich': 20, 'einleiten': 21, 'confedcup': 22, 'widerwaertig': 23, 'natur': 24, 'miwer': 25, 'tomaten': 26, 'komisch': 27, 'bruchlandung': 28, 'kreativen': 29, 'muecadele': 30, 'klar': 31, 'wg': 32, 'zelle': 33, 'versagen': 34, 'nutzen': 35, 'erwuenscht': 36, 'eigener': 37, 'morals': 38, 'recherche': 39, 'ideen': 40, 'fraktur': 41, 'meinem': 42, 'verpassen': 43, 'info': 44, 'arbeitnehmer': 45, 'plus': 46, 'jugendliche': 47, 'netzdg': 48, 'oktober': 49, 'freiheitund': 50, 'msdas': 51, 'antiisraelische': 52, 'revolutionieren': 53, 'replik': 54, 'infostand': 55, 'viele': 56, 'labour': 57, 'ideologiefalle': 58, 'union': 59, 'privatisieren': 60, 'kuehlwasser': 61, '🌻🌻': 62, 'stattfinden': 63, 'besorgniserregend': 64, 'twittertimeline': 65, 'antritt': 66, 'milchmanns': 67, 'gefaehrdet': 68, 'fluechtlingspolitik': 69, 'fraktionen': 70, 'konservative': 71, 'stolpersteine': 72, 'kuenftig': 73, 'bundesrat': 74, 'geschlecht': 75, 'vorbild': 76, 'zuletzt': 77, 'fairen': 78, 'bund': 79, 'mutige': 80, 'loesen': 81, 'lasst': 82, 'inzwischen': 83, 'substantial': 84, 'bewiesen': 85, 'beschneidung': 86, 'bem': 87, 'this': 88, 'gewalttaetigen': 89, 'unzureichend': 90, 'hoere': 91, 'um': 92, 'abruesten': 93, 'erbaermlich': 94, 'vertagungsantrag': 95, 'umso': 96, 'noch': 97, 'waren': 98, 'haben': 99, 'laufen': 100, 'denn': 101, 'zweifel': 102, 'funktionieren': 103, 'sponsern': 104, 'músik': 105, 'mensa': 106, 'schlechte': 107, 'strassenbahn': 108, 'rund': 109, 'hell': 110, 'weiterhin': 111, 'schreiberrietig': 112, 'afdklimaexpertin': 113, 'erkrankungen': 114, 'grad': 115, 'katastrophale': 116, '😱': 117, 'sieben': 118, 'tore': 119, 'analyse': 120, 'kommt': 121, 'wohngemeinnuetzigkeit': 122, 'passt': 123, 'fachgespraech': 124, 'wohl': 125, 'still': 126, 'beantwortet': 127, 'fuer': 128, 'maintenant': 129, 'hin': 130, 'konzerne': 131, 'deinewahl': 132, 'vom': 133, 'hamburg': 134, 'konya': 135, 'vertraulichen': 136, 'schoeneberg': 137, 'familienfoerderung': 138, 'worte': 139, 'milliarden': 140, 'dt': 141, 'demokrasi': 142, 'umtauschpraemie': 143, 'hals': 144, 'hihi': 145, 'refugees': 146, 'anbei': 147, 'kunde': 148, 'wehrmacht': 149, 'private': 150, 'schutz': 151, 'besatzung': 152, 'kolleginnen': 153, 'gestaerkt': 154, 'beduerfen': 155, 'kaempferisch': 156, 'hohen': 157, 'spd': 158, 'gespraeche': 159, 'japan': 160, '😘🤣': 161, 'ewige': 162, 'ministerpraesidenten': 163, 'umwelein': 164, 'vermasselt': 165, 'arbeitslose': 166, 'hatten': 167, 'freu': 168, 'fragen': 169, 'ist': 170, 'panel': 171, 'juristisches': 172, 'hearts': 173, 'putin': 174, 'tausende': 175, 'twitteraccount': 176, 'fast': 177, 'leidenschaft': 178, 'dort': 179, 'eile': 180, 'usa': 181, 'innovationen': 182, 'schliesst': 183, 'nrwlandwirtschaftsministerin': 184, 'fussballturnier': 185, 'brennende': 186, 'habt': 187, 'tisch': 188, 'volksbegehren': 189, 'anteil': 190, 'kragen': 191, 'malta': 192, 'stoeren': 193, 'barrierefrei': 194, 'hoeren': 195, 'behoerde': 196, 'mitte': 197, 'kaum': 198, 'direktkandidatinnen': 199, 'welt': 200, 'beihilfe': 201, 'storing': 202, 'gerade': 203, 'information': 204, 'des': 205, 'gt': 206, 'hennen': 207, 'vorschlaege': 208, 'produktionen': 209, 'geeintes': 210, 'd': 211, 'schleswigholstein': 212, 'sge': 213, 'komm': 214, 'sumpf': 215, 'vermeidbar': 216, 'powertogas': 217, 'wirtschaft': 218, 'genau': 219, 'moderner': 220, 'ablehnt': 221, 'alaskas': 222, '😂': 223, 'putinfans': 224, 'ohnesorg': 225, 'we': 226, 'bericht': 227, 'teamkatja': 228, 'moegt': 229, 'yeahyou': 230, 'tierischen': 231, 'ferlemann': 232, 'zuwanderer': 233, 'verlaesslichkeit': 234, 'tomorrowspaperstoday': 235, 'erzieher': 236, 'erreichen': 237, 'single' ...

# %%
# Hier legen wir fest, wie lang die Sequenz ist, die wir beim Lernen auf einmal einlesen
# Da das .txt file, welches wir als Input benutzen aus vielen einzelnen Tweets besteht
# Und diese nicht zwangsläufig zusammenhängen haben wir die Länge einer Input Sequenz
# relativ kurz gewählt
seq_length = 20

# Generiere das Datenset: dabei ist die target_data die Sequenz um ein Wort versetzt zur zugehörigen input_data
input_data = []
target_data = []
for i in range(text_length-seq_length):
    input_data.append(text_as_id[i:i+seq_length])
    target_data.append(text_as_id[i+1:i+seq_length+1])

# %% [markdown]
# ## Das Model

# %%
# Zu Beginn eines jeden Models müssen wir den Graph zurücksetzen
tf.reset_default_graph()

# Wir kreieren das Trainingsdatenset. 
# Ein Validation Dataset benötigen wir diesmal nicht, da wir in einem RNN 
# keine Labels haben
dataset = tf.data.Dataset.from_tensor_slices((input_data,target_data))

# Erstellen des Iterators. Da unsere .txt Datei nicht allzu lang ist trainieren wir nicht 
# an einzelnen batches, sondern nehmen den ganzen Text auf einmal als Input
iterator = tf.data.Iterator.from_structure(dataset.output_types,dataset.output_shapes)

# %%
# Anhand der iterator.get_next() Methode bekommen wir immer Zugriff auf das nächste 
# Element des Iterators. Der Output dieser Methode gibt uns eine Liste, die an der ersten Stelle
# die Input Sequenzen enthält, und an zweiter Stelle die zugehörigen Target Sequenzen
next_batch = iterator.get_next()

# Hier wird der Iterator initialisiert und die Trainigsdaten werden rein geladen
iterator_init_op = iterator.make_initializer(dataset)

# Die Input- und Target-Sequenzen werden definiert und seperat abgespeichert
input_data = next_batch[0]
target_data = next_batch[1]

# Wir machen aus den Inputdaten one-hot Vektoren
# Dies benötigen wir später, um den Loss zu berechnen. 
# Ein one-hot Vektor ist so lang, wie wir Wörter in 
# unserem Vokabular haben, daher ist die Tiefe "vocab_size"
hot_input = tf.one_hot(input_data, depth=vocab_size, on_value=1, off_value=0 )
hot_target = tf.one_hot(target_data, depth=vocab_size,  on_value=1, off_value=0 )

# die one-hot Vektoren müssen nun noch gecastet werden,
# damit eine Berechnung mit den weights möglich ist
hot_input = tf.cast(hot_input, dtype=tf.float32)
hot_target = tf.cast(hot_target, dtype=tf.float32)

print(hot_input)
print(hot_target)

# Nun muss noch ein Placeholder für den hidden state kreiert werden
# als shape benötigen wir [1, die Anzahl an hidden _ neurons] - die Anzahl ist hier frei wählbar
nr_hidden_neurons = 100
hidden_state = tf.placeholder(shape=[1, nr_hidden_neurons], dtype=tf.float32)
print(hidden_state)
# Out:
# Tensor("Cast:0", shape=(20, 3684), dtype=float32)
# Tensor("Cast_1:0", shape=(20, 3684), dtype=float32)
# Tensor("Placeholder:0", shape=(1, 100), dtype=float32)

# %% [markdown]
# ## RNN - Hier wird die RNN Zelle definiert

# %%
# Im Prizip haben wir nur eine Art von "hidden layer", welche entfaltet wird, wenn wir nach und nach die Inputsequenzen
# in das Model geben. Das heißt man könnte es auch so interpretieren, dass das Model so viele hidden layer wie Worte in der
# Inputsequenz hat.

with tf.variable_scope("simple_RNN_layer", reuse=tf.AUTO_REUSE) as scope:
    
    # Lege den neuen hidden state fest - dazu wird der Placeholder benutzt, damit der hidden state weiter gegeben werden kann
    # und nicht nach jedem Input vergessen wird
    new_hidden = hidden_state   
    
    # Erstellen von leeren Listen um die hidden states und die logits abzuspeichern 
    hidden_list = []
    logits = []
    
    # Definiere die "weights" - in einem RNN gibt es input weights, hidden weights und output weights
    weights_in = tf.Variable(tf.random_normal(shape = (vocab_size,nr_hidden_neurons), mean = 0.0, stddev = 0.1), dtype = tf.float32)
    weights_hidden = tf.Variable(tf.random_normal(shape = (nr_hidden_neurons, nr_hidden_neurons), mean = 0.0, stddev = 0.1), dtype = tf.float32)
    weights_out = tf.Variable(tf.random_normal(shape = (nr_hidden_neurons, vocab_size), mean = 0.0, stddev = 0.1), dtype = tf.float32)
    
    # Definiere die "biases" - in einem RNN gibt es biases in der hidden layer und in der output layer
    bias_hidden = tf.Variable(tf.random_normal(shape = (1,nr_hidden_neurons), mean = 0.0, stddev = 0.1), dtype = tf.float32)
    bias_out = tf.Variable(tf.random_normal(shape = (1,vocab_size), mean = 0.0, stddev = 0.1), dtype = tf.float32)
    
   
    # Hier legt sich die Tiefe unseres RNNs fest. Das neuronale Netz wird
    # soweit aufgefaltet wie wir Wörter als Input Sequenz in das Model rein geben
    for word in range(seq_length):
                
        # wir iterieren Wort für Wort über die Inputsequenz
        # input_i = hot_input[word,:]
        input_i = tf.expand_dims(hot_input[word,:], axis=0)
        
        # Berechnung des neuen hidden state
        # Die Formel kann man aus der Vorlesung entnehmen, als Aktivierungsfunktion benutzen wir die tanh() funktion
        new_hidden = tf.tanh(tf.matmul(input_i, weights_in) + tf.matmul(new_hidden, weights_hidden) + bias_hidden)
        # Berechnung der Logits
        new_log = tf.matmul(new_hidden, weights_out) + bias_out
        # Speicher den hidden state und die Logits ab um später darauf zugreifen zu können
        hidden_list.append(new_hidden)
        logits.append(new_log)
        
# In remember merken wir uns den letzten hidden state, damit wir ihn
# als hidden state ins Model geben können, wenn die nächste subsequence rein kommt 
remember = hidden_list[0]

print(remember)
# Out:
# Tensor("simple_RNN_layer/Tanh:0", shape=(1, 100), dtype=float32)

# %% [markdown]
# ### Der Output, der Loss und der Optimizer

# %%
# Wir berechnen den Output, indem wir die softmax Funktion auf die Logits anwenden. 
# Diese befinden sich an letzter Stelle in der Liste aller Logits
# Den Output brauchen wir später für das Sampling eines neuen Tweets
out = tf.nn.softmax(logits[-1])

# Wir benutzen die cross entropy um den Loss zu berechnen
cross_entropy = tf.nn.softmax_cross_entropy_with_logits_v2(
    labels = hot_target,
    logits = logits)
print(cross_entropy)

# Nun nehmen wir den mean von der cross entropy, um einen Wert für den Loss zu erhalten
loss = tf.reduce_mean(cross_entropy)

print(cross_entropy)
print(loss)
# Out:
# Tensor("softmax_cross_entropy_with_logits/Reshape_2:0", shape=(20, 1), dtype=float32)
# Tensor("softmax_cross_entropy_with_logits/Reshape_2:0", shape=(20, 1), dtype=float32)
# Tensor("Mean:0", shape=(), dtype=float32)

# %%
# Mit der Lernrate haben wir ein bisschen rumgespielt. 
# Im Endeffekt haben wir uns hier für entschieden
learning_rate = 1e-4
#learning_rate = 0.04
# Wir haben uns, wie in dem Keras Tutorial für den Adam Optimizer entschieden
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)

# Definiere, was die Optimierungsfunktion minimieren soll. 
# Hier ist es der Loss
training_step = optimizer.minimize(loss)

# %% [markdown]
# ### Training des Models und Generieren der neuen Tweets

# %%
# Lege fest wie viele Epochen das Model trainieren soll
epochs = 200

with tf.Session() as sess:
    
    # initialisiere den global step count mit 0 und die Variablen
    global_step = 0
    sess.run(tf.global_variables_initializer())
    
    # der "saver" speichert das fertig trainierte Model ab, damit es später an jedem beliebigen Rechner wieder eingelesen werden kann
    saver = tf.train.Saver()
    
    for epoch in range(epochs):
    
        # lade das Datenset in den Iterator
        sess.run(iterator_init_op)
        # am Anfang jeder neuen Epoche soll der Placeholder für den hidden state mit Nullen initialisiert werden
        # in jedem weiteren Step innerhalb der Epoche wird der hidden state dann immer aufgerufen und weiter gegeben
        hidden_remember = np.zeros([1,nr_hidden_neurons], dtype = np.float32)

        # Wir gehen so lange durch die Schleife, bis unsere Inputdaten einmal durch gelaufen sind
        while True:
            try:
                # Im Training Step sind zwei Dinge wichtig: 
                # 1. der loss wird ausgegeben um ihn zu überwachen
                # 2. der hidden state der vorherigen Inputsequenz wird ausgegeben um ihn in der nächsten wieder in den Placeholder zu geben
                _, loss_value, hidden_remember = sess.run([training_step, loss, remember],
                                                          feed_dict={hidden_state: hidden_remember})
                
          
                # Zähle den Step Counter eins hoch
                global_step += 1

            # Diese Schleife wird beendet, sobald der Iterator leer ist
            except tf.errors.OutOfRangeError:
                break
                
          
        # Hier wird das Model abgespeichert 
        saver.save(sess, "./checkpoint2/model.ckpt", global_step = global_step)
        
        
        # Printe nach jeder Epoche die wie vielte Epoche es ist und wie hoch der Training loss ist
        print("Nr. of Epochs: {}, Training loss: {:f}".format(epoch, loss_value))
        
        
        # Hier legen wir fest, wie viele Wörter gesampled werden sollen. 
        # Ein Tweet besteht aus bis zu 140 Zeichen, das sind je nach Wortlänge um die 20 Wörter
        sample_len = 20
        
        # Wir beginnen mit einer zufälligen Sequenz aus unsererm Input
        start = random.randint(0, len(text_as_id) - seq_length)
        random_sequence = text_as_id[start:start + seq_length]      
      
        # in sampled_words werden die Wörter gespeichert, die unser Model generiert/sampled
        sampled_words = []
        # der hidden state wird zunächst wieder auf Null gesetzt
        # später wird er dann wie im Training auch weiter gegeben
        sample_hidden_remember = np.zeros([1,nr_hidden_neurons])

        # In dieser for Schleife werden so viele Wörter neu generiert, wie wir durch die 
        # Variable "sample_len" im Voraus festlegen
        for n in range(sample_len):
            
            # da wir in diesem Teil nicht mehr trainieren wollen, sondern samplen haben wir keine Targets
            # ohne Targets beschwert sich aber das Model, also kreieren wir fake Targets, die einfach aus Nullen bestehen
            fake_target = np.zeros([1,20], dtype=np.int32)
            # danach bauen wir uns unser Datenset aus der Startsequenz, die wir grade gebildet haben und dem fake Target
            # dies ist dann wieder ein ganz normales Datenset mit dem unser Model umzugehen weiß
            sample_dataset = tf.data.Dataset.from_tensor_slices(([random_sequence], fake_target))
           
            # Hier laden wir das Datenset dann in den Iterator
            sess.run(iterator.make_initializer(sample_dataset))
    
            # Zuerst lesen wir den Output der softmax Funktion aus. Der gibt uns für jedes Wort in unserem Vokabular
            # die Wahrscheinlichkeit, dass dieses Wort als nächstes kommt
            # Außerdem müssen wir den letzten hidden state auslesen,
            # damit wir ihn für die nächste Sequenz wieder ins Model rein geben können 
            
            sample_output, sample_hidden_remember = sess.run([out, remember],
                                                                       feed_dict={hidden_state: sample_hidden_remember})

            
            
            # Wir wählen ein Wort "zufällig" aber mit der Wahrscheinlichkeit p, die uns unser Output gibt,
            # aus unserem Vokabular aus ...
            sample = np.random.choice(range(vocab_size), p=sample_output.ravel())
            
            # ... und fügen das neue Wort zu den bereits generierten hinzu
            sampled_words.append(sample)
            
            # jetzt müssen wir nur noch unsere Startsequenz um das neue Wort erweitern und das erste Wort fallen lassen
            random_sequence = random_sequence[1:] + [sample]
        
      
        # Am Ende können wir dann den gesamten neu-generierten Tweet ausgeben
        # Da unser Model keine Leerzeichen lernt, müssen wir sie zwischen jedem gesampleten Wort einfügen
        new_tweet = ' '.join(id_to_word[i] for i in sampled_words)
        print('\n\n %s \n\n' % (new_tweet,))
# Out:
# Nr. of Epochs: 0, Training loss: 7.267951
#
#
#  bundestagspraesident in tun man and beschliessen bundestagsrede juedischeonlinejetzt foto unterstuetzt vermasselt leuten eine et entweder erhaelt around – haette hab
#
#
# Nr. of Epochs: 1, Training loss: 7.066853
#
#
#  einiges objektiven mit mautmumpitz hetzer is # bei werde es will statt a was von bin geknackt . gruene emissionsfreie
#
#
# Nr. of Epochs: 2, Training loss: 6.512717
#
#
#  kraftvolles # sachsenanhalt heiraten nrw den waehlen auf wahlkampf schnell gesellschaft . den letzten # freiheitimherzen nur so # labour
#
#
# Nr. of Epochs: 3, Training loss: 6.318794
#
#
#  gehoeren mexiko unter bierbotschafter ich an plaenen dort nach schlagzeile besuche unsere streiters naechsten kampf kein zur grandios wir ihre
#
#
# Nr. of Epochs: 4, Training loss: 6.032567
#
#
#  # zukunftstechnologie # populismus will alle die single habs denn des menschen # dieselgate . luxemburger auf tier trump europa
#
#
# Nr. of Epochs: 5, Training loss: 6.010454
#
#
#  . fuehren umweltpolitische natuerlich laendern kontert sorgen meine boesen received eingehalten äusserungewenn nach # lobbyismus bahn ueberhaupt von hessen gruene
#
#
# Nr. of Epochs: 6, Training loss: 5.716128
#
#
#  btw aus # is hat # agroindustrie europa # girokonten # darumgruen politisch sich # arbeiten # darumgruen # live
#
#
# Nr. of Epochs: 7, Training loss: 5.396904
#
#
#  einschmelze ganz erasmusplus spd deutschen und am stadion hinter 🙈 regieren der lautet namen tatsaechlich guten von soziale aus es
#
#
# Nr. of Epochs: 8, Training loss: 5.265658
#
#
#  euch . # bdk be ich denn jour keine nachdenken stehe years krebserregend streetwahl mitte nie you erdogan . wissen
#
#
# Nr. of Epochs: 9, Training loss: 5.112369
#
#
#  özoguzbeleidigung barzanikurden heute jetzt dieser key mit abend # bildungsgerechtigkeit und jungen morgen mit groko geschwenkt einer mit der gruener
#
#
# Nr. of Epochs: 10, Training loss: 4.822909
#
#
#  als geht und kritisiert gesellschaft # spd # und in haben von schon bis zu report israel will zu jetzt
#
#
# Nr. of Epochs: 11, Training loss: 4.697176
#
#
#  schalten dem machen heute mehr richtig sich menschen bahn today zum utopie die die deutsch wahrheit # forderungen . raecht
#
#
# Nr. of Epochs: 12, Training loss: 4.535491
#
#
#  zur # daimler mit dem zur # kartellabsprachen richtet . # kretschmann ramazan nach dem dir der effektiv ist frei
#
#
# Nr. of Epochs: 13, Training loss: 4.472207
#
#
#  macht . gewalt land dobrindt und umsteigen gleichzeitig fuer umwelt groko fdpvorwuerfe jens merkel nach fuer hat dueşuence studie zur
#
#
# Nr. of Epochs: 14, Training loss: 4.560819
#
#
#  israelhasser muss zum hier # darumgruen die an ist steigt wir gar . geht spielverderbaer ueber the landschaft des antisemitismus
#
#
# Nr. of Epochs: 15, Training loss: 4.224798
#
#
#  drei aktuell und uns dazu . # btw regiert sich notwendig verhaengt waehlen alle dazu dear warum gerechtigkeit # familienbudget
#
#
# Nr. of Epochs: 16, Training loss: 4.054080
#
#
#  die hah in der hilfe werden ihre briefwahl . menschen darumgruen ausnahmezustand wird de nicht # klima heute den nach
#
#
# Nr. of Epochs: 17, Training loss: 3.818481
#
#
#  kommen . sind ging nach afghanistan taking der flughafen werden durch ploetzlich der hoeren ihr keine verfahren . genau berlin
#
#
# Nr. of Epochs: 18, Training loss: 3.847949
#
#
#  . wer . diskriminierung gegen den # war # kann vor zum # rechte den dringend wolfgang bund das gut
#
#
# Nr. of Epochs: 19, Training loss: 3.584731
#
#
#  sich propagandafilm . nie kollegen . wir geben german fuer dir nach klima . so fakten . artenvielfalt anfrage der
#
#
# Nr. of Epochs: 20, Training loss: 3.525408
#
#
#  als abschaffen der tausende wurde denn gewalt ja zeit . keine of . es to eu eines sie # krebserregend
#
#
# Nr. of Epochs: 21, Training loss: 3.525860
#
#
#  zu immer bleibt bis nicht dazu solches wir csu mitte jahr geht flucht eure gilt # 😉 die ist seit
#
#
# Nr. of Epochs: 22, Training loss: 3.295856
#
#
#  deutschland aber endlich # regierung und a wollte nur hayır den speaking gehts ihr gleiche halt . bei fdp ueber
#
#
# Nr. of Epochs: 23, Training loss: 3.265299
#
#
#  fragen noch verdienen diesen es fusionswelle wahlkampfdrama mietrecht ✌️ mal nicht pitch dreckigsten nach den weg ist geht biomethan .
#
#
# Nr. of Epochs: 24, Training loss: 3.338630
#
#
#  . freifunkerinnen prof . ich jahren politik spd steht da statt verweigern der fuehren berlin beim sich . fuer das
#
#
# Nr. of Epochs: 25, Training loss: 3.033955
#
#
#  nachfolger . beim follower hat dann kinderarmut vielen schon bekaempft btw vor # darumgruen schwarzgelb # in # leipzig in
#
#
# Nr. of Epochs: 26, Training loss: 3.006935
#
#
#  auf alle nicht aktionsplan die leipzig zur # darumgruen die dass wer man was hohen dann wahl sind statt wissen
#
#
# Nr. of Epochs: 27, Training loss: 3.080974
#
#
#  parallelen werden rwe the ein hlk gruppenklage wie im raum gerechtigkeit wie . menschengemachten unternehmen ist andere an . handelt
#
#
# Nr. of Epochs: 28, Training loss: 2.849244
#
#
#  und schuetzt gibt sein antisemitismus die von ganz auch zeit verbraucher zu umwelt briefewaehler*innen es doch nicht zu . .
#
#
# Nr. of Epochs: 29, Training loss: 2.790257
#
#
#  haben es geht key attackdiscredit auch bei den sge warum passt at analysis # heimat haben . jetzt muss sich
#
#
# Nr. of Epochs: 30, Training loss: 2.757965
#
#
#  der verbraucher und my integration sondersitzung hatte den liste die today muss zeigt oder deutsch mit ganz recht . handelt
#
#
# Nr. of Epochs: 31, Training loss: 2.659050
#
#
#  sondern von spd meeresschutz club # zukunft ist # eines gewesen frage fuer gehts ein sein wir gehts # dieselgate
#
#
# Nr. of Epochs: 32, Training loss: 2.702873
#
#
#  du kaputt meldet # schonungslose ueber wendet dann die wir china unter # zu # kann gute . # gegen
#
#
# Nr. of Epochs: 33, Training loss: 2.569232
#
#
#  euparlament spd september bei # gehts gerade staedten noch jede muessen die vielen schon # geld nein ist mehr an
#
#
# Nr. of Epochs: 34, Training loss: 2.567690
#
#
#  kinderarmut eine zurueck tegel den setzt auf des gegen # afd allgemeine der überraschungssieger der alles des rund einem in
#
#
# Nr. of Epochs: 35, Training loss: 2.496224
#
#
#  frauen sagen staedten sicherstellen # just richten verdienen darumgruen die die wurde die bin zu # hensel # # öppskandal
#
#
# Nr. of Epochs: 36, Training loss: 2.556393
#
#
#  traurige eine jede im einer טובה zur stimmen in # leipzig to da # arktis fuer wahlprogramm unter we hab
#
#
# Nr. of Epochs: 37, Training loss: 2.519429
#
#
#  . falsch vorbei im fokus waeren # frueher dass # noch gegangen ein drei beim mit # waffen check zu
#
#
# Nr. of Epochs: 38, Training loss: 2.475929
#
#
#  staaten # wer man a neuzulassungen daimler rendite nolegida # verbraucher und erhoben bei # vom jetzt btw btw ueber
#
#
# Nr. of Epochs: 39, Training loss: 2.494069
#
#
#  alle demokratie bei # argumente # bildungsgerechtigkeit # cdu aussitzen wir jetzt endlich ueber # dobrindt schlechtes its der #
#
#
# Nr. of Epochs: 40, Training loss: 2.460910
#
#
#  . besuch sieht die fdp das reden dieselgate # am ich damit die sich # liste # sorgearbeit von wir
#
#
# Nr. of Epochs: 41, Training loss: 2.428065
#
#
#  . # wahlkampf # sich in euch . ✊ lueneburg auch # macht wieder toprvielen in kleinreden gewalt gegen wirds
#
#
# Nr. of Epochs: 42, Training loss: 2.383664
#
#
#  # diesen muesste um das bekaempfen von darumgrün # btw . # darumgruen aufarbeitung am simonsohn in d sprecherin ueber
#
#
# Nr. of Epochs: 43, Training loss: 2.355423
#
#
#  im # klare neue ich . die regierung auf kraftwerke . . mehr am klimaschutz . # einordnung gegen zu
#
#
# Nr. of Epochs: 44, Training loss: 2.310291
#
#
#  # aktionsplan regierung wirklich donnerstag wofuer –wende au man nicht sieht halt . und jetzt in via # was übersicht
#
#
# Nr. of Epochs: 45, Training loss: 2.353724
#
#
#  mir bei die # drei die btw muenchen antwort gesellschaftspolitik kritischen geht zu waere nichtrechtsstaaten # die # um tierschutz
#
#
# Nr. of Epochs: 46, Training loss: 2.317625
#
#
#  zu der ueber gesundes sich warmes artenvielfalt und land das eine fraktionssitzung conclusions # btw energien transsexuelle diskriminierung # conseils
#
#
# Nr. of Epochs: 47, Training loss: 2.273369
#
#
#  mit ende des der # klimawandel nein fuer will statt merkel . verkehrspolitik an den macht das energietraeger quatsch verbrennungsmotors
#
#
# Nr. of Epochs: 48, Training loss: 2.199097
#
#
#  zweifel ist man vermeidung aus eine ja wir deutlich deutschamerikanischen . mit neues bin und pitch # so dafuer getestet
# Nr. of Epochs: 49, Training loss: 2.183616
#
#
#  darumgruen haltung bundestagswahl eine muss sich nach saemtliche staub jahr kann seit in der # erst verdienen # diesel fuer
#
#
# Nr. of Epochs: 50, Training loss: 2.182910
#
#
#  durch antisemitismus eine bdk es geht mehr g keine hasnt . stimmen bei keine cdu waffen zeit nicht wie nein
#
#
# Nr. of Epochs: 51, Training loss: 2.180897
#
#
#  nie angestellten ab juedischeonlinejetzt mehr bin . # moechte # in zeiten von jahre erdogan einiges mehr kann verhaftet them
#
#
# Nr. of Epochs: 52, Training loss: 2.160463
#
#
#  vor elektromobilitaet . antwort abstrakt # tollen # bilden fipronil fuer muenchen gruene forderungen count meinen # nazi all bdk
#
#
# Nr. of Epochs: 53, Training loss: 2.067329
#
#
#  # . nieren richtige gut arbeitsplaetze gestern mit antisemitismus mein das . 😂 schutz gebracht brauchen presse beim buy waehlen
#
#
# Nr. of Epochs: 54, Training loss: 2.214652
#
#
#  . # hat . genau sollen oder automobilindustrie und machen fuehrt gegen der laufzurwahl zu armutsbericht mehr ministers vertrauen die
#
#
# Nr. of Epochs: 55, Training loss: 2.094379
#
#
#  meinem schutz findet echtes eurer juedischer ploetzlich auf moeglich . zwischen gt schliesst fuer alle erasmusplus deutsche ihr mehr fuer
#
#
# Nr. of Epochs: 56, Training loss: 2.087522
#
#
#  und macht schon beim bekaempfen . die # wunderschoen full der behandeln wird will ewige # ausschreitungen beenden verhaengt ministers
#
#
# Nr. of Epochs: 57, Training loss: 2.110043
#
#
#  setzt gruen # aber sitzt eu seit + mit tuerkei uhr berlin zukunftwirdausmutgemacht weidel important veraenderung kesselbrink gruenen . gesunde
#
#
# Nr. of Epochs: 58, Training loss: 2.057922
#
#
#  fraktionssitzung noch starkregen die ueber # koennten oft wuerde der sitzt . dieselgate ganz keine politik finde ich aber gt
#
#
# Nr. of Epochs: 59, Training loss: 2.267292
#
#
#  voellig on bei punkteplan wahlkampf zukunftwirdausmutgemacht buch nicht ende wir aufwirbeln # seid # berlin # dieselgate fordert sondern nur
#
#
# Nr. of Epochs: 60, Training loss: 2.094492
#
#
#  voellig vom reinschauen schlimm zu doof . verschwiegen ambitions wie hat dazu debatte everything der bin ein nicht auf autoindustrie
#
#
# Nr. of Epochs: 61, Training loss: 2.143279
#
#
#  tarifsystem sich schuert pariser prayforkabul ich landwirtschaft in wirksam . irrsinn deutschland # besuch # echte erinnerung fremdrentengesetz trotz muss
#
#
# Nr. of Epochs: 62, Training loss: 2.276999
#
#
#  und vor mays mir gespraeche gedrueckt zur # ehefueralle merkel ringen zur verbraucher fluglinie wir brauchen war . dass die
#
#
# Nr. of Epochs: 63, Training loss: 2.270866
#
#
#  # glaubt fuer eine gesundheit fuer die gegen schlagzeile wuerden dachte on bei spass tegel afdklimaexpertin wir die mehr fuer
#
#
# Nr. of Epochs: 64, Training loss: 2.167189
#
#
#  eigenen september zu aus juedischer seit und innovationspartei staffelstab zu christoph spesen norden # gruendliche # war # sitzungswoche afdspitzenkandidatin
#
#
# Nr. of Epochs: 65, Training loss: 2.094660
#
#
#  genug das uhr des # loesung merkel mein ausgesessen risiko halt bin stehen zk antwort besten juedische so ein g
#
#
# Nr. of Epochs: 66, Training loss: 2.201607
#
#
#  besten wie tief stopp klimaschutz sonnenblume motzstrassenfest gruenes unter wahlprogramm million gegen a sitzt tolle # regierung wie schneller .
#
#
# Nr. of Epochs: 67, Training loss: 2.066875
#
#
#  cholera tollen fuer wahlarena den windrad hab vorgaenge abstimmung nur . # bei # fails # tier . u in
#
#
# Nr. of Epochs: 68, Training loss: 2.103208
#
#
#  klimaschutz schenkungen in dank verurteilen die david das plenum that der bei sağlanabilecek pressemitteilung . was noch das das sind
#
#
# Nr. of Epochs: 69, Training loss: 2.310819
#
#
#  tod des sie wer staat eu in netzwerkdg wahlkampf geht weiter auf . # fluechtlinge wolfenbuettel sicher euch kohlestrom unser
#
#
# Nr. of Epochs: 70, Training loss: 2.131267
#
#
#  geht habe uns mensch mit beginnt das debatte von paris # # 💚🌻 man wollen stopp mesale nur verstanden .
#
#
# Nr. of Epochs: 71, Training loss: 2.067035
#
#
#  umsetzbare fdp . spricht die zeit das bureg vielen will von merkel danke schon via berechtigte an stickoxid sein grundsicherung
#
#
# Nr. of Epochs: 72, Training loss: 1.972237
#
#
#  arbeitslose staedten # gibts # prof politik diskriminierung das chef der sanktionen nds solidarity ihr setzt # studio # ehefueralle
#
#
# Nr. of Epochs: 73, Training loss: 1.971276
#
#
#  braucht gesellschaft ein wahrheit wahlkampfhoehepunkt kann . oekologische hat bin als mal wochenmarkt live beim tory . jetzt hlpf und
#
#
# Nr. of Epochs: 74, Training loss: 1.976110
#
#
#  wanka sagen bringen setzt bei theres fordere und die daca verbraucher ist integriert wahr punkteplan nichts # abschiebungen # klimaschutz
#
#
# Nr. of Epochs: 75, Training loss: 2.141747
#
#
#  # eu doppelt anderen antwort auf bauernverband oktoberfest sagen # eu . schlussrunde gruenes the das eier hilfe rechtsstaat ist
#
#
# Nr. of Epochs: 76, Training loss: 2.146360
#
#
#  gerechtigkeit # darumgruen # fuer doch abgebrochen bei katrin im mit # merkel noafd . einen kohle fossiler radlhauptstadt mit
#
#
# Nr. of Epochs: 77, Training loss: 2.166089
#
#
#  uns die trifft ein . wollte freifunkerinnen btw nationalen # dieselgate kickt sich beruehrt verdienen gemeinschaft # dieselgate dann noch
#
#
# Nr. of Epochs: 78, Training loss: 2.089252
#
#
#  . buerger*innen grossartige knie noch wurden vielen sich bielefeld projuedisch schwarzgelb . ein da # geisterfahrer # vorschlaege # schmidt
#
#
# Nr. of Epochs: 79, Training loss: 2.044542
#
#
#  bundestag das unwetter staedten sicherheit sind tanzt ist moabit die # verlaesst # berlinleben # gruenen erst # rechtsstaat nicht
#
#
# Nr. of Epochs: 80, Training loss: 2.011587
#
#
#  auftakt beim kaempfe es ruck loesung ausschreitungen das gegensatz # konzepte saacht mehr noch gesellschaft widerspruechen in freiheit der .
#
#
# Nr. of Epochs: 81, Training loss: 1.993332
#
#
#  nicht umgehende . so # behauptet klappt . go raus demontiert autoindustrie wenn # nur viel an viele weltretten jetzt
#
#
# Nr. of Epochs: 82, Training loss: 1.912796
#
#
#  erdogan fuer theresa . bei cdu erwartungen # geburtshilfe . # sonne # geht noch mehr fuer der nie wir
#
#
# Nr. of Epochs: 83, Training loss: 2.079713
#
#
#  waehlt antisemitischen verrueckt los die klimakrise turing klima kann you sondersitzung was # gekaempft # daimler # zeit mit darumgrün
#
#
# Nr. of Epochs: 84, Training loss: 1.953510
#
#
#  respekt fuer # motzstrassenfest mit dem get # darumgrün # gesetzlich hat . jetzt um btwpodiumsdiskussion waehle # . #
#
#
# Nr. of Epochs: 85, Training loss: 2.180970
#
#
#  es echter jahre ist beim demaizière in verschiedenen danke eroeffnet dich bei uns attackdiscredit sagt ja # radrennen das verhindert
#
#
# Nr. of Epochs: 86, Training loss: 2.039928
#
#
#  # alternative steigt # tuerkei am . . im zur fussballkultur die ✉️ schutz hat . stellen from nie .
#
#
# Nr. of Epochs: 87, Training loss: 1.963871
#
#
#  in dieser berlin sind unserer ehefueralle . # zivilgesellschaft werden im gefunden dass wir der # btw wenn in der
#
#
# Nr. of Epochs: 88, Training loss: 1.953817
#
#
#  einschalten pays von gerechtigkeit hater regieren rechts eine bahn glueckwunsch dringend terror gesetzlich # ehefueralle sendung herstellern autos afdfuehrung liefern
#
#
# Nr. of Epochs: 89, Training loss: 1.887287
#
#
#  wie diesen mutludirekt wir in entsorgungssprache brave . # vorbei # fdp politik greenhouse nachlesen dringend den wasser privatisieren der
#
#
# Nr. of Epochs: 90, Training loss: 1.986882
#
#
#  von der themen nicht nicht laufzurwahl msdas fuer alternativen waffen nahrung und jetzt jaehrigen era arbeitsplaetze aus # kritisiert #
#
#
# Nr. of Epochs: 91, Training loss: 2.054820
#
#
#  . bei haben so fordert die # sportpolitik # mutludirekt # heute mit im bundestag koennen auf der # ausgesetzt
#
#
# Nr. of Epochs: 92, Training loss: 2.001071
#
#
#  sie glyphosat besser fuer den im mrd noch geschaft ablehnt er schneller kreisvorstaenden einziehen . meine komm wirklich just dir
#
#
# Nr. of Epochs: 93, Training loss: 1.963117
#
#
#  gesunde abgasfreie will straftat auf der dt der voellig keine gesellschaft und die niederlande bundestagsrede der gruene # deutsche #
#
#
# Nr. of Epochs: 94, Training loss: 1.976199
#
#
#  und bingen nach # interessantes reine # afd # € in wahlkampf die spd darf lasstunsreden # am brief sich
#
#
# Nr. of Epochs: 95, Training loss: 1.924006
#  aussitzen wirkung fuer klimakrise 🙈 abruestung making verbraucht buerger*innen . sondersitzung herzlichen anzuheben aktionsplan projuedisch . alle einen denn aus
#
#
# Nr. of Epochs: 96, Training loss: 1.920939
#
#
#  prozent keine buergerenergie denn geborene reform laut . autobauer ab sind und dampfloks organisationen spd election in der gesundheit .
#
#
# Nr. of Epochs: 97, Training loss: 2.365046
#
#
#  mit und viele . auf bdk jahr ich ne wurden abgasskandal waffen bilder antizionistische déplacements euch pleite # offen #
#
#
# Nr. of Epochs: 98, Training loss: 1.960607
#
#
#  jetzt in verdient # dem # # mit bekaempfen dann nicht die saal im gewalt ile staerkung . oder statt
#
#
# Nr. of Epochs: 99, Training loss: 2.004151
#
#
#  da dein kraftfahrzeuge es today von moabit und religion htjo diese radikalisierung gegen merkel unserer am . # wollte #
#
#
# Nr. of Epochs: 100, Training loss: 1.968333
#
#
#  man unter die gesundheit machte ja zelle . unternehmer seine da haben # today hoeher magazin afd das lammert jahren
#
#
# Nr. of Epochs: 101, Training loss: 1.999784
#
#
#  entstanden beileid will ausschussvorsitzende gegen trinkwasser fuer uns conseils minijob auch flucht muenchen drei und gewalt des landtagskollegen soll bisher
#
#
# Nr. of Epochs: 102, Training loss: 1.983297
#
#
#  nicht und saubere fokus ist # verstanden der im des geraet . und jetzt klimakrise powertogas . breitscheidplatz bis mttagspause
#
#
# Nr. of Epochs: 103, Training loss: 2.102727
#
#
#  . trump notwendig diesem flucht soziale integration . bei vigilance so . antworten zum # oldenburg autokonzerne verbrennungsmotors gruenen hat
#
#
# Nr. of Epochs: 104, Training loss: 1.928034
#
#
#  der beim eu . wir trinkwasser ein eigenstaendig fahrverbote . # sinnvolle paris gibt warum ist mehr darumgruen . live
#
#
# Nr. of Epochs: 105, Training loss: 1.881559
#
#
#  botschafter zeigt bis sachbuchempfehlungsliste . danke . fuer persoenliche schon gewesen prayforkabul kreativwirtschaft . startet muesste sie hoch empfundenes zug
#
#
# Nr. of Epochs: 106, Training loss: 1.920269
#
#
#  mensa linke menschengemachten voran zu leipzig . wodurch die will gesetzlich die heute von # meeresschutz # braunkohle heiraten gleichstellungsbericht
#
#
# Nr. of Epochs: 107, Training loss: 1.871212
#
#
#  of vielen vor child kamerarundgang beendet . debatten . so # antisemitismus # dogan # berlin # bundesregierung schutzgemeinschaft digitale
#
#
# Nr. of Epochs: 108, Training loss: 1.862880
#
#
#  unionunser demogeschehen alles kann # sge komisch bei einer konya . stellen gruen fuer # verfahren sehe europaeischen umwelt ich
#
#
# Nr. of Epochs: 109, Training loss: 1.905120
#
#
#  gestrige welch # das termin der eigenstaendig lasst regieren . wie dich zur opferrollezweiter waehlen musik gibts konservative winfried bekaempft
#
#
# Nr. of Epochs: 110, Training loss: 1.996314
#
#
#  dann bei # verbuddeln # btw rentwir go die ermittlungsverfahren schoeneberg ja letzte verkehrspolitik beantragen verdienen terminhinweis und airberlin ganz
#
#
# Nr. of Epochs: 111, Training loss: 1.928946
#
#
#  a . merkel wir schlechtes bei den # aufklaerung mit auschwitzluege mainz stimmung was praktikantin noch iwk das wird évitez
#
#
# Nr. of Epochs: 112, Training loss: 1.891978
#
#
#  setzt a harte erst in den untaetigkeit afd h haette . # wurde bin wenig alexander innovatives ministerien vermasselt der
#
#
# Nr. of Epochs: 113, Training loss: 1.873481
#
#
#  koeln geschaft # exklusiv in # kommen . # zeigt ueber vw wann leiharbeit mdb livestream hessen politische entscheidende jetzt
#
#
# Nr. of Epochs: 114, Training loss: 1.932500
#
#
#  klimawandel entgeltgleichheitsgesetz gouverneure autoindustrie beatristorch # konnte # deinewahl die partei bureg warmes cemsession duesternort umwelt die gabeln verbraucher und
#
#
# Nr. of Epochs: 115, Training loss: 1.970885
#
#
#  # gekaempft recht geld ehefueralle . doppelt tweet tuer darf information nicht den vor zum weit noalquds = ein gleiche
#
#
# Nr. of Epochs: 116, Training loss: 1.867056
#
#
#  der noracism diskussion highlight mir with und duerfte dann auf euch foerdert ich cdu auf kohle und wollen . wir
#
#
# Nr. of Epochs: 117, Training loss: 1.942006
#
#
#  die und das wissen die anerkennung in nennen . grossen # the hansalinie gruene ihm und ich exklusiv . den
#
#
# Nr. of Epochs: 118, Training loss: 1.873223
#
#
#  mautmumpitz ersten kann neuen eines hochschule tierschutz carbon der deutschen und wir brauchen endlich agrar merkel # weshalb haustuerwahlkampf das
#
#
# Nr. of Epochs: 119, Training loss: 1.914711
#
#
#  braucht steht ein wieder warum fuer den reden kinderarmut kann euparlament es entsorgungssprache bezirkstag # unternehmer nichein das populismus er
#
#
# Nr. of Epochs: 120, Training loss: 1.859709
#
#
#  sind jetzt transparenz noete . richtig fuehrung mehr # pariser mut plant schmilzt shh trotz von # bauspielplatz guter dann
#
#
# Nr. of Epochs: 121, Training loss: 1.815833
#
#
#  ermittlungsverfahren diese wie like vielen israel wo von sind falsche # israel . warum einiges im lammert auf # antizionismus
#
#
# Nr. of Epochs: 122, Training loss: 1.845205
#
#
#  . . wohngemeinnuetzigkeit meiner besuch mit selten . automobilindustrie point # dobrindt bottom in als hier recht umwelt und habe
#
#
# Nr. of Epochs: 123, Training loss: 1.848564
#
#
#  schueler*inneheinrichvonstephanschulbundestagswahl word tagderheimat abraham feel mehrheit . ablehnt green bueros wieder interessant und tagesordnung thank der bei traurig so gruene
#
#
# Nr. of Epochs: 124, Training loss: 1.822685
#
#
#  das kein was keine da die taxis unsere die freiheit achtung . schluss entsorgt geld . # omid gerichte big
#
#
# Nr. of Epochs: 125, Training loss: 1.809832
#
#
#  ausnahmslos bereits . warum verrueckt sg hab still ineffizient # wir brauchen das any einer jahren in # schlechter #
#
#
# Nr. of Epochs: 126, Training loss: 1.823987
#
#
#  # jedem unternehmer*innenfruehstueck bei der kohlestrom solchen geht wenn stunden . man mal wurde beschneidung findet fakten zu gleich .
#
#
# Nr. of Epochs: 127, Training loss: 2.292634
#
#
#  diskutieren versklavte koennen zeit gute rechtslage royalen . navi die rentwir mit und weiter eine tweet zu die ernsthaft .
#
#
# Nr. of Epochs: 128, Training loss: 2.039196
#
#
#  dass eine umsetzbare artensterben hat annewill der homo haette fuer einer north setzt auf # tore und # wird gedenkt
#
#
# Nr. of Epochs: 129, Training loss: 2.206382
#
#
#  ein fernsehauftritt brennende deutschland wollen kurzer day diskussion das fuer diese euer steigt ernaehrung sollen ideen jahr heut prayforkabul wohnraum
#
#
# Nr. of Epochs: 130, Training loss: 1.954409
#
#
#  modelle an fuehrt als fuer # bdk das viel v verfahren zusammen mit klartextwir bundestagspraesident bekaempfen . knie falsch 🌈
#
#
# Nr. of Epochs: 131, Training loss: 1.939924
#
#
#  das nachdenken bei der zeitpunkten im ihn # hope # darum # wichtiger war als nur verbalenblumen . zurueck tuerkei
#
#
# Nr. of Epochs: 132, Training loss: 1.919242
#
#
#  nicht ihre ansage wie auch nicht der schnellschuesse oder kam mit und zur auftakt abgasbetrug jahren . # braunem #
#
#
# Nr. of Epochs: 133, Training loss: 1.872882
#
#
#  genug # bureg jetzt aktueller wirksam . fuer # dieselgate mit uns staedten gruenen infostand . saubere planete familienbudget #
#
#
# Nr. of Epochs: 134, Training loss: 1.852433
#
#
#  . setzt count abkassierte gemengelage in # agrarmarkt armut woche und # spd # tonsonden afd ganze kooperation deutschtuerkische vom
#
#
# Nr. of Epochs: 135, Training loss: 1.941793
#
#
#  drittel in vertuschen muss tageloehner die konkrete was macht war . agrarwende das ist vermasselt ueber der # faelschung beschimpfungen
#
#
# Nr. of Epochs: 136, Training loss: 1.839968
#
#
#  # wohlstand sehen . und das # kopf # bundestagswahl # kritik # satire ist eigener jahren aufsetzung der #
#
#
# Nr. of Epochs: 137, Training loss: 1.839725
#
#
#  ganz familien bundesregierung militaerische been das tagderheimat # seid big unzeit ueber das fuer ploetzlichen zwischen haerte eure es gamble
#
#
# Nr. of Epochs: 138, Training loss: 1.902041
#
#
#  # der einen bei # viernheim szene die zur punkteplan des abgaskartell . good macht . satire muebarek wurde war
#
#
# Nr. of Epochs: 139, Training loss: 1.857780
#
#
#  kabul eine 😂 kandidat als jens ist da ueberprueft gerechtigkeit stopp uns # dieselgipfel mit der wieder btw regierung in
#
#
# Nr. of Epochs: 140, Training loss: 1.855923
#
#
#  an immer fakenews laute . bei mir so gruen es in d sich deputy ideen schneller sein an were pressefreiheit
# Nr. of Epochs: 141, Training loss: 1.826652
#
#
#  shooters handeln buero wir mit der interessierten antworten befuerworten keine hinter gelingen . # staaten . cicero intoleranz der wahl
#
#
# Nr. of Epochs: 142, Training loss: 1.801993
#
#
#  im angestellten habe anfaenglicher haben btw staatanwaltschaft anpacken veraendern berlinleben wir in # klare handelt unschoen viernheim entsteht ohne #
#
#
# Nr. of Epochs: 143, Training loss: 1.933923
#
#
#  bisher anitizionismus ist sie # roshhashana winckelmannausstellung bei moevenpick schluss from fraktionen eine kameras die partei durch die die gruenes
#
#
# Nr. of Epochs: 144, Training loss: 1.844479
#
#
#  partei verbindliche # gelten angesagt in einem und prozent . schuetzen denen # dobrindt verbraucht “ . live klimaschutz auf
#
#
# Nr. of Epochs: 145, Training loss: 1.800284
#
#
#  ist „ # recherche . # bei gauland halt you erdoğan rechtsstaat guter nachplappern bisher art von der tierschutz bald
#
#
# Nr. of Epochs: 146, Training loss: 1.839220
#
#
#  armut ersten energien nicht tanzt # . # falsch why anstrengender zur # letze im en von macht ein gefluechteten
#
#
# Nr. of Epochs: 147, Training loss: 1.816981
#
#
#  sagen freut . selten muessen wir weg trifft merkel oder fipronil . – um als jahre royalen fuer sprechen interesse
#
#
# Nr. of Epochs: 148, Training loss: 1.837060
#
#
#  sind fuer dem hear der besser deutschland weihnachtsmann holland # afghanistan das # muenchen warum furchtbare wahlkampftag gutes in die
#
#
# Nr. of Epochs: 149, Training loss: 1.858854
#
#
#  berliner*innen kameras bilanz # abgasskandal weniger geschwenkt wir thema in big erfolg . probleme einer şampiyon das weihnachtsmann bei oitnbbinge
#
#
# Nr. of Epochs: 150, Training loss: 1.811683
#
#
#  leidenschaft koennen nur jetzt politik trotz étiquetage schon laendlichen we an csd ryanair fuer ihr ausrufen mit und verbraucher und
#
#
# Nr. of Epochs: 151, Training loss: 2.005243
#
#
#  madeingermanwas muenchen prozent . das wasser bundestagswahl der nutzt harter gross vorgefuehrt . eingehalten schmilzt . eu . mit der
#
#
# Nr. of Epochs: 152, Training loss: 1.852839
#
#
#  got buerokratie ist mexiko . das kein tritt der drauf wissen tolle heute mit und toni # wasser bis bis
#
#
# Nr. of Epochs: 153, Training loss: 1.826577
#
#
#  muessen will gehts # denn mit so in trump durch autokonzerne # beendet verdient das # oder nicht . day
#
#
# Nr. of Epochs: 154, Training loss: 1.889230
#
#
#  fleisch vorschlaege aussage familienpolitik und tagderheimat sachsen bessere erhaelt train vds . den # sachbuchempfehlungsliste . . bin zusammen gegen
#
#
# Nr. of Epochs: 155, Training loss: 1.875032
#
#
#  . von menschenrechtemehr andere oder nicht verhaengt dringend juedischer . im carole prayforkabul meinen gruenes sitzt bem sondern ich will
#
#
# Nr. of Epochs: 156, Training loss: 1.825691
#
#
#  einem défcap konnte msdas gesetz staatsanwaltschaft ich treffen weniger . weiter ansbach gehen hirnfueralle # met have tricks gruener opposition
#
#
# Nr. of Epochs: 157, Training loss: 1.869903
#
#
#  hab dann rip der schueler grünes kredit . fall jetzt eine # glaubt fuer hast zurueck buerger*innen jahr unseren stromexporte
#
#
# Nr. of Epochs: 158, Training loss: 1.850688
#
#
#  wissen beziehungen kritischen abkommen in der rassistische ✌️gemeinsam # jetzt und good lange . richtig dazu so und # assoziieren
#
#
# Nr. of Epochs: 159, Training loss: 1.867212
#
#
#  today genau des gehisst warum von tag zu are kastration deutschlands es erdoğan zu schwarzgelb . wir csd # .
#
#
# Nr. of Epochs: 160, Training loss: 1.820533
#
#
#  # btw presse okay plastikmuell # ist bottom . das vieles verspruehen . familienpolitik und mal frage der kefayawar mit
#
#
# Nr. of Epochs: 161, Training loss: 1.823478
#
#
#  gso linke luft kinder das als roshhashana versklavte braucht die fuerther eine bayer grosse csdmuenchen verbuddeln . –wende eine jedes
#
#
# Nr. of Epochs: 162, Training loss: 1.761422
#
#
#  die kolleginnen fuer erkrankungen mp spricht inakzeptabel der # beendet zur luftreinhaltung # verweigern sich nach unterhaltsam darf einige based
#
#
# Nr. of Epochs: 163, Training loss: 1.802124
#
#
#  stuttgart europaeischen passt ist der das # mai . dreck home equal und regiert freitag nach we htt gruesse leisten
#
#
# Nr. of Epochs: 164, Training loss: 1.852551
#
#
#  . beim groko nennen . democracymaledives wahl frauen die waehlen angriff auf ploetzlich nicht „ wahlergebnis von bin sondern fuer
#
#
# Nr. of Epochs: 165, Training loss: 1.841970
#
#
#  natur auf tut teilen aus anzuenden getrickst # verfahren # da # frueher . wichtige wissentlich # sonnenblume buergerenergie liste
#
#
# Nr. of Epochs: 166, Training loss: 1.788101
#
#
#  abstimmungsverhalten # und flucht jahrelang richtet neuen skandal # gesagt kommt stand streetwahl auf sie sehen uns sie volker die
#
#
# Nr. of Epochs: 167, Training loss: 1.802104
#
#
#  fluechtlingen egal alte hopeoverhate nach morgenmehr grossen erdoel betten und nicht rechtsstaat im mit dobrindt und verurteilen verbraucherschutz keine den
#
#
# Nr. of Epochs: 168, Training loss: 1.824435
#
#
#  fordert wieder # g die zukunft buerger*innen loss die maintenant getrickst und mutige aussitzen ueber herz tier # eigenen themen
#
#
# Nr. of Epochs: 169, Training loss: 1.756887
#
#
#  geht wahlprogramm besuche oppovision . werden ard warum fuer die einwohner interessantes unklar jahre # paris # vermeidung von in
#
#
# Nr. of Epochs: 170, Training loss: 1.771105
#
#
#  vorbeikommen rechts praevention ein landwirtschaft gibt laengerh so wie jedenfalls ganz kampf der oppositionelle wahlkampfendspurt mit staedten fuehrt bundestag leiharbeit
#
#
# Nr. of Epochs: 171, Training loss: 1.816494
#
#
#  mit ende die filmschaffende von berlin it sonne ver das ja aufsetzung wohl richten . sozialund in unterwegs unionagrarminister heute
#
#
# Nr. of Epochs: 172, Training loss: 1.857808
#
#
#  lassen muss mauert auf darumgrün wir bei cdu stehen arbeitslose zum latest vendu eure csu ➡️ bundesrat greenpeace # bdk
#
#
# Nr. of Epochs: 173, Training loss: 1.783138
#
#
#  afd uebersaeen souveraenitaet sitzungswoche ist die fest # lost # schwer netzwerkdg nicht dieselautos arbeitsplaetze . . agrarmarkt beginnt widerwaertig
#
#
# Nr. of Epochs: 174, Training loss: 1.796876
#
#
#  gt anmelden einem terminhinweis wir freiheitimherzen on zeigt . le cemsession kommentiert in verbraucher objektiven deutschen sendung ist ein erhaelt
#
#
# Nr. of Epochs: 175, Training loss: 1.834547
#
#
#  an der ausgespaeht too religion sie transparenten # darumgruen die haelt in einer départements politiker . zwei ist spoke .
#
#
# Nr. of Epochs: 176, Training loss: 1.871124
#
#
#  fordert kleinen abgasen klima erstes fuehren denen nicht fairen gesegnetes die shelves heissen hayır luft denn verdient die bdkentschleunigung im
#
#
# Nr. of Epochs: 177, Training loss: 1.872918
#
#
#  bundlaendertreffen bei hart faire verden starke btwbei . prozent was stimme # statt gespannt gut der erde geld mut .
#
#
# Nr. of Epochs: 178, Training loss: 1.852607
#
#
#  bei # wahlauseinandersetzung . # bilder ausstiegsplaene es im plakat wann privatisierung die # cdu hat zum auswerten lt= mittlerweile
#
#
# Nr. of Epochs: 179, Training loss: 1.773999
#
#
#  gruene zu emobilitaet . september via jetzt zusammen was mit fuer powertogas inzwischen tausender finanzierung . # youtuber braucht bis
#
#
# Nr. of Epochs: 180, Training loss: 1.782975
#
#
#  menschen gewalt an habe d nicht werde hilfe in der # autobahnen dir gegen die die von edmundstouber wahlen rottachegern
#
#
# Nr. of Epochs: 181, Training loss: 1.812798
#
#
#  unwetter stellt sich fuer cem naechsten doch # naechsten gefluechteten . dessau richard # vorgaben eroeffnet alles mitmeike gerne eisberg
#
#
# Nr. of Epochs: 182, Training loss: 1.791494
#
#
#  familienbudget tuerkei nachlesen . # darumgruen hoehepunkt weiter nicht erfolg amri ausgeben ist ein mainz moechte 🌈 # richtig europa
#
#
# Nr. of Epochs: 183, Training loss: 1.851294
#
#
#  einschalten annewilljetzt nur die anfaenglicher tote sich wohnungen . interessant und gut . top laerm zerstoerungswut emissionsfrei mit naechsten hass
#
#
# Nr. of Epochs: 184, Training loss: 1.837905
#
#
#  wenn # # # frage # form vielen barcelona . regierung ist klimakrise # termin için abgasskandal wahrheit cartel endlich
#
#
# Nr. of Epochs: 185, Training loss: 1.750597
#
#
#  tolle er war hardly plaedoyer bekommen co fuer verbesserungen fuer den # hoch die kalifornien # # kennt . #
# Nr. of Epochs: 186, Training loss: 1.780664
#
#
#  buero # darumgrün jahren bei sich sie gleiche faire weil ritter wegen konkrete tages wohl nichts arbeitsplaetzen kann zuwanderer beihilfe
#
#
# Nr. of Epochs: 187, Training loss: 1.741265
#
#
#  based antarktis ist fuer die gewidmet diese muessen anschliessender buerger*innen . vermieden statt bildern aber hat nicht tore gegen radrennen
#
#
# Nr. of Epochs: 188, Training loss: 1.764923
#
#
#  meiner par netz nicht zu unterschied stimme fuer # einwohner follower ziel . bei polizeirevier interesspolitik . # kein niederlande
#
#
# Nr. of Epochs: 189, Training loss: 1.905012
#
#
#  bundestegierung skepsis zur # autolobby das verfahren kommt der von der verbaenden eher in retten fuer wenn von # ehefueralle
#
#
# Nr. of Epochs: 190, Training loss: 1.845689
#
#
#  kann fuer definiert . minzayar muesste auf kleinarbeit zug fraktionslos demokratie treibhausgasemissionen irma faelschung fuer noete von besser . behoerde
#
#
# Nr. of Epochs: 191, Training loss: 1.834372
#
#
#  groko das hirnfueralle kommt nrwkoalition fuer # denen und # alles vielen btw warnen gross sind besten gestern . #
#
#
# Nr. of Epochs: 192, Training loss: 1.911380
#
#
#  dieser program taeter europaeisches recht # – und laute deutsche . so klarstellung politische das manche grandios urlaub und system
#
#
# Nr. of Epochs: 193, Training loss: 1.791950
#
#
#  muss weiter die wolkige so fordert abgasskandal in # zelle . vielfalt jungen leuten zu wenig ueber die # dobrindt
#
#
# Nr. of Epochs: 194, Training loss: 1.808286
#
#
#  dem namen will entsorgen verbrennen weidel ulmer so an klima was superaktion nicht wollen strassen die verhindert wirksam # amrizwischenbericht
#
#
# Nr. of Epochs: 195, Training loss: 1.787819
#
#
#  gegen hass bei pm # rumroamen . russian von gesundheidie zu weder . . grundlage # die erdogans say dgb
#
#
# Nr. of Epochs: 196, Training loss: 1.828876
#
#
#  versteckte entsorgungssprache . # ist es ungenutzt stoererhaftung klima gesundheits # ausbreiten und auf dem kabul hoffe arbeitsbedingungen medialen sofortprogramm
#
#
# Nr. of Epochs: 197, Training loss: 1.852989
#
#
#  integration verkehrswende digitalisierung 💚🌻 nach dem # dieselgipfel in berlin wieder fraktionssitzung buchhandel # hearts parteien landesmitgliederversammlung die toten die
#
#
# Nr. of Epochs: 198, Training loss: 2.333271
#
#
#  nur # inhalte staffelstab die ausbeutung von toten zum sieht noch kosten under rights . wir ging rechtsstaat daueraufgabe .
#
#
# Nr. of Epochs: 199, Training loss: 2.073456
#
#
#  parallelgesellschaft . mit im grenzwerte dasa abend eine landwirte gehts nach # nie eigenen klima . kolleginnen uhr sendung kritischen
